# %%
#Q1 : Create a string and print it.
string='Digipodium is great'
print(string)
# Out:
# Digipodium is great

# %%
# Q2:Take a string input and print it's length.
string1=input('Enter a string :')
print(len(string1))
# Out:
# 10

# %%
# Q3:Print the last word of the string Python is great using slices.
string2='Python is great'
print(string2[-5:len(string2)])
# Out:
# great

# %%
# Q4: Print the each word in different line of string python is everywhere.
str1='''python\nis\neverywhere'''
print(str1)
# Out:
# python
# is
# everywhere

# %%
# Q5: Print the string Hello World! in reverse.
str2="Hello World!"
print(str2[::-1])
# Out:
# !dlroW olleH

# %%
# Q6: Convert the string How are you? in uppercase.
a="How are you?"
print(a.upper())
# Out:
# HOW ARE YOU?

# %%
# Q7: Convert the string How Is It Going? in lowercase.
b="How Is It Going?"
print(b.lower())
# Out:
# how is it going?

# %%
# Q8: Join the following list by spaces( ) and print the result.
words = ['Python', 'is', 'easy', 'to', 'learn']
new=' '.join(words)
print(new)
# Out:
# Python is easy to learn

# %%
# Q9 : Print a multiline string using a single print
print('''this is the biggest house i have ever seen\ni think its is also great\nabd the best too''')
# Out:
# this is the biggest house i have ever seen
# i think its is also great
# abd the best too

# %%
#Q10 : Print this string to move to newline '\n' is used. (results should look exactly like the provided string)
print ("to move to newline '\\n' is used")
# Out:
# to move to newline '\n' is used

# %%
#Q11 :Print a variable with some text using a single print function, output should look like following.the variable is 15
var="the variable is 15"
print(var)
# Out:
# the variable is 15

# %%
#Q12 : concatenate the following strings and print the result
s1 = 'python '
s2 = 'is '
s3 = 'great.'
j = s1+s2+s3
print(j)
# Out:
# python is great.

# %%
# Q13 : Print # 20 times without using a loop
val='#'
print(val*20)
# Out:
# ####################

# %%
#Q 14 :Print numbers from 1 to 9, each on a seperate line, followed by a dot, output should look like the following-
for i in range(10):
    if i>0:
        print(i,'.')
# Out:
# 1 .
# 2 .
# 3 .
# 4 .
# 5 .
# 6 .
# 7 .
# 8 .
# 9 .

# %%
# Q15 : Ask user to input a sentence and print each word on a different line.
sen=input("Enter a sentence")
for i in sen.split():
    print(i)
# Out:
# i
# am
# a
# great
# man
# and
# great
# human

# %%
# Q16: Ask user to input a string and check if the string ends with '?' 
ab=input("enter a string")
if ab[-1]=='?':
    print('it ends with ?')
else:
    print("it does not end with a ? ")
# Out:
# it ends with ?

# %%
# Q17: Ask user to input a string and print how many times e appeared in the string
az=(input("input a string"))
print(az.count('e'))
# Out:
# 7

# %%
# Q 18 : Check if the user input is a number.
ac=input("enter something")
if ac.isnumeric()== True:
    print("it is a number")
else:
    print("it is not a number")
# Out:
# it is a number

# %%
# Q 19 :Remove the extra spaces in beginning and in the end of the following string text = '   this is not a good string 
text="   this is not a good string "
text=text.strip()
print(text)
# Out:
# this is not a good string

# %%
# Q 20 :Ask user to input string, print found if any of the character is upper case.
a1=input("Enter a string")
print(a1)
for z in a1:
    if z.isupper()==True:
        print("found")
    else:
        print("no upper case found")
# Out:
# i Am very bad
# no upper case found
# no upper case found
# found
# no upper case found
# no upper case found
# no upper case found
# no upper case found
# no upper case found
# no upper case found
# no upper case found
# no upper case found
# no upper case found
# no upper case found

# %%
# Q 21 Extract names from the following string and store them in a list.
names = 'Joe, David, Mark, Tom, Chris, Robert'
names=names.split()
print(names)
# Out:
# ['Joe,', 'David,', 'Mark,', 'Tom,', 'Chris,', 'Robert']

# %%
# Q 22 :In the following string, add aye in the end of every word and print the results.
text = 'this is some text'
text=text.split()
s='aye'.join(text)
print(s)
# Out:
# thisayeisayesomeayetext

# %%
# Q 23 :ask user to enter a string and check if the string contains fyi
us=input("Enter a string:")
if 'fyi' in us:
    print("present")
else:
    print("absent")
# Out:
# present

# %%
# Q 24 : Remove all the special characters and numbers from the following string

text = '%p34@y!*-*!t68h#&on404' 
for v in text:
    if v.isalpha()==False:
       text=text.replace(v,'')
print(text)
# Out:
# python

# %%
# Q 25 :calculate the average word length of the following paragraph.
q="this is a paragraph which is written just for the purpose of providing content to let the average word length be calculated"
len(q)
p=len(q.split())
average=len(q)/p
print(average)
# Out:
# 5.590909090909091
